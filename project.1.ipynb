# %%
import pandas as pd
df=pd.read_csv("ac2.csv")

# %%
df
# Out:
#          Brand       Model   Stars   Weights  PowerUsage  \
# 0       Voltas  2023 Model  3 Star   1.5 Ton      975.26
# 1           LG  2023 Model  3 Star   1.5 Ton      852.44
# 2       Voltas  2023 Model  5 Star   1.5 Ton      751.28
# 3    Whirlpool  2023 Model  3 Star   1.5 Ton         NaN
# 4       Daikin  2023 Model  3 Star   0.8 Ton      548.84
# ..         ...         ...     ...       ...         ...
# 475      Haier  2023 Model  3 Star   1.5 Ton     1020.54
# 476     Daikin         NaN  3 Star  2.02 Ton     1372.85
# 477     CRUISE         NaN  2 Star   1.5 Ton     1238.57
# 478         NU  2023 Model  5 Star   1.5 Ton      759.56
# 479      Lloyd         NaN  3 Star       NaN         NaN
#
#                                                 Rating  RoomSize    Price
# 0                                                  4.2  150 sqft  ₹32,990
# 1                                                  4.2  150 sqft  ₹35,990
# 2                                                  4.2  150 sqft  ₹39,490
# 3                                                  3.9  150 sqft  ₹32,790
# 4                                                  4.1   90 sqft  ₹25,999
# ..                                                 ...       ...      ...
# 475  <module 'numpy' from 'C:\\Users\\Admin\\anacon...  150 sqft  ₹36,490
# 476  <module 'numpy' from 'C:\\Users\\Admin\\anacon...       NaN  ₹58,881
# 477  <module 'numpy' from 'C:\\Users\\Admin\\anacon...  150 sqft  ₹27,990
# 478                                                3.5  150 sqft  ₹33,990
# 479                                                4.3   90 sqft  ₹30,990
#
# [480 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       240 non-null    object
#  2   Stars       467 non-null    object
#  3   Weights     324 non-null    object
#  4   PowerUsage  352 non-null    float64
#  5   Rating      480 non-null    object
#  6   RoomSize    478 non-null    object
#  7   Price       480 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 30.1+ KB

# %%
df.isnull().sum()
# Out:
# Brand           0
# Model         240
# Stars          13
# Weights       156
# PowerUsage    128
# Rating          0
# RoomSize        2
# Price           0
# dtype: int64

# %%
df["Model"].mode()
# Out:
# 0    2023 Model
# Name: Model, dtype: object

# %%
df["Model"]=df["Model"].fillna(value="2023 Model")

# %%
df["Model"].isnull().sum()
# Out:
# 0

# %%
df["Stars"].mode()
# Out:
# 0    3 Star
# Name: Stars, dtype: object

# %%
df["Stars"]=df["Stars"].fillna(value="3 star")

# %%
df["Stars"].isnull().sum()
# Out:
# 0

# %%
df["Weights"].mode()
# Out:
# 0    1.5 Ton
# Name: Weights, dtype: object

# %%
df["Weights"]=df["Weights"].fillna(value="1.5 Ton")

# %%
df["Weights"].isnull().sum()
# Out:
# 0

# %%
df["PowerUsage"].mean()
# Out:
# 892.86921875

# %%
df["PowerUsage"].median()
# Out:
# 867.16

# %%
df["PowerUsage"]=df["PowerUsage"].fillna(value="866.495")

# %%
df["PowerUsage"].isnull().sum()
# Out:
# 0

# %%
df["PowerUsage"]=df["PowerUsage"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       480 non-null    object
#  2   Stars       480 non-null    object
#  3   Weights     480 non-null    object
#  4   PowerUsage  480 non-null    float64
#  5   Rating      480 non-null    object
#  6   RoomSize    478 non-null    object
#  7   Price       480 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 30.1+ KB

# %%
df["Rating"].mode()
# Out:
# 0    4.2
# Name: Rating, dtype: object

# %%
df["Rating"]=df["Rating"].fillna(value="4.2")

# %%
df["Rating"]=df["Rating"].replace("[^\d+]","",regex=True).astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       480 non-null    object
#  2   Stars       480 non-null    object
#  3   Weights     480 non-null    object
#  4   PowerUsage  480 non-null    float64
#  5   Rating      480 non-null    float64
#  6   RoomSize    478 non-null    object
#  7   Price       480 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 30.1+ KB

# %%
df["Price"].mode()
# Out:
# 0    ₹32,990
# Name: Price, dtype: object

# %%
df["Price"]=df["Price"].fillna(value=32990)

# %%
df["Price"]=df["Price"].replace("[^\d+]","",regex=True).astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       480 non-null    object
#  2   Stars       480 non-null    object
#  3   Weights     480 non-null    object
#  4   PowerUsage  480 non-null    float64
#  5   Rating      480 non-null    float64
#  6   RoomSize    478 non-null    object
#  7   Price       480 non-null    int32
# dtypes: float64(2), int32(1), object(5)
# memory usage: 28.3+ KB

# %%
df["RoomSize"].mode()
# Out:
# 0    150 sqft
# Name: RoomSize, dtype: object

# %%
df["RoomSize"]=df["RoomSize"].fillna(value="150 sqft")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       480 non-null    object
#  2   Stars       480 non-null    object
#  3   Weights     480 non-null    object
#  4   PowerUsage  480 non-null    float64
#  5   Rating      480 non-null    float64
#  6   RoomSize    480 non-null    object
#  7   Price       480 non-null    int32
# dtypes: float64(2), int32(1), object(5)
# memory usage: 28.3+ KB

# %%
df
# Out:
#          Brand       Model   Stars   Weights  PowerUsage  Rating  RoomSize  \
# 0       Voltas  2023 Model  3 Star   1.5 Ton     975.260    42.0  150 sqft
# 1           LG  2023 Model  3 Star   1.5 Ton     852.440    42.0  150 sqft
# 2       Voltas  2023 Model  5 Star   1.5 Ton     751.280    42.0  150 sqft
# 3    Whirlpool  2023 Model  3 Star   1.5 Ton     866.495    39.0  150 sqft
# 4       Daikin  2023 Model  3 Star   0.8 Ton     548.840    41.0   90 sqft
# ..         ...         ...     ...       ...         ...     ...       ...
# 475      Haier  2023 Model  3 Star   1.5 Ton    1020.540     3.0  150 sqft
# 476     Daikin  2023 Model  3 Star  2.02 Ton    1372.850     3.0  150 sqft
# 477     CRUISE  2023 Model  2 Star   1.5 Ton    1238.570     3.0  150 sqft
# 478         NU  2023 Model  5 Star   1.5 Ton     759.560    35.0  150 sqft
# 479      Lloyd  2023 Model  3 Star   1.5 Ton     866.495    43.0   90 sqft
#
#      Price
# 0    32990
# 1    35990
# 2    39490
# 3    32790
# 4    25999
# ..     ...
# 475  36490
# 476  58881
# 477  27990
# 478  33990
# 479  30990
#
# [480 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Brand         0
# Model         0
# Stars         0
# Weights       0
# PowerUsage    0
# Rating        0
# RoomSize      0
# Price         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       480 non-null    object
#  1   Model       480 non-null    object
#  2   Stars       480 non-null    object
#  3   Weights     480 non-null    object
#  4   PowerUsage  480 non-null    float64
#  5   Rating      480 non-null    float64
#  6   RoomSize    480 non-null    object
#  7   Price       480 non-null    int32
# dtypes: float64(2), int32(1), object(5)
# memory usage: 28.3+ KB

# %%
# Univariate

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Q1. Counting Brand names of AC

# %%
df["Brand"].value_counts()
# Out:
# Brand
# Panasonic     44
# Voltas        43
# Blue          41
# LG            41
# Lloyd         39
# SAMSUNG       38
# Daikin        33
# Hitachi       33
# CARRIER       28
# Godrej        26
# Haier         17
# IFB           13
# Whirlpool     12
# ONIDA         10
# Midea          9
# MarQ           9
# TOSHIBA        8
# CANDY          8
# realme         7
# O              7
# Thomson        4
# MOTOROLA       3
# NU             2
# Frigidaire     1
# Sansui         1
# Kelvinator     1
# Hisense        1
# CRUISE         1
# Name: count, dtype: int64

# %%
## Catergorical

# %%
plt.xlabel("Brand")
plt.title("Brand distribution")
sns.countplot(x="Brand",data=df,palette="viridis")
plt.xticks(rotation=100)
plt.show()

# %%
## Q2.Print price distribution

# %%
df["Price"].value_counts()
# Out:
# Price
# 32990    13
# 33990     9
# 38990     9
# 43990     8
# 32999     7
#          ..
# 47000     1
# 31707     1
# 37489     1
# 40999     1
# 58881     1
# Name: count, Length: 263, dtype: int64

# %%
## Countinous

# %%
sns.histplot(data=df, bins=10, kde=False,color="viridis")
plt.title('Price Distribution Histogram')
plt.xlabel('price')
plt.ylabel('Frequency')

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## Bivariate

# %%
### Categorical and continous

# %%
#### Q3.Get a rating for different brands.

# %%
# Group data by brand and calculate the mean rating
brand_rating_mean = df.groupby("Brand")["Rating"].mean().sort_values()


# Plot the data
plt.figure(figsize=(5, 4))
brand_rating_mean.plot(kind="bar")
plt.xlabel("Brand")
plt.ylabel("Mean Rating")
plt.title("Brand Distribution by Mean Rating")
plt.xticks(rotation=100)

# Show the plot
plt.show()

# %%
### Continous and continous

# %%
#### Q4.Plota Price according to PowerUsage of their distribution

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x='PowerUsage', y='Price', data=df, color='blue')
plt.title('Scatter Plot: PowerUsage vs. Price')
plt.xlabel('PowerUsage')
plt.ylabel('Price')

# Show the plot
plt.show()

# %%
#### Q5.Calculating a relationship of columns

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')


# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # Calculate the correlation matrix
# ----> 2 correlation_matrix = df.corr()
#       4 # Create a correlation heatmap
#       5 plt.figure(figsize=(8, 6))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Voltas'

# %%
### Multivariate

# %%
#### Categorical and Countinous

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Brand', y='PowerUsage', data=df, palette='Set2')
plt.title('Bar Plot: Average Power Usage by Brand')
plt.xlabel('Brand')
plt.ylabel('Power Usage')
plt.xticks(rotation=100)  # Adjust the rotation angle as needed
plt.show()

# %%
#### Q5.Getting brands of 5star rating

# %%
five_star_df = df[df['Rating'] == 4.0]

# Create a count plot to visualize the brands with 5-star ratings
plt.figure(figsize=(10, 6))
sns.countplot(x='Brand', data=five_star_df, palette='Set2')
plt.title('Count Plot: Brands with 5-Star Ratings')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=100)

# Show the plot
plt.show()

# %%
#### Categorial and Countinous

# %%
#### Q6.Draw a plot for average price and powerusage by brand

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Brand', y='Price', data=df, ci=None, color='skyblue', label='Price')
sns.barplot(x='Brand', y='PowerUsage', data=df, ci=None, color='green', label='PowerUsage')
plt.title('Average Price and Powerusage Capacity by Brand')
plt.xlabel('Brand')
plt.ylabel('Value')
plt.xticks(rotation=100)
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_11856\1173794693.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Brand', y='Price', data=df, ci=None, color='skyblue', label='Price')
# C:\Users\pavan\AppData\Local\Temp\ipykernel_11856\1173794693.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Brand', y='PowerUsage', data=df, ci=None, color='green', label='PowerUsage')
